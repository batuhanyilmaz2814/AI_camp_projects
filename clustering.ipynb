# %%
from sklearn.cluster import KMeans, DBSCAN
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_blobs(n_samples=100, centers=4, cluster_std=2, random_state=31)
plt.scatter(X[:,0], X[:,1], c="black", s=100, alpha=1, label="Original Data")

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c=y_kmeans, cmap="viridis", s=50)
plt.title("K-means Clustering")
plt.show()

# %%
dbscan = DBSCAN(eps=2.8, min_samples=4)
y_dbscan = dbscan.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=y_dbscan, cmap="viridis", s=50)
plt.title("DBSCAN Clustering")
plt.show()
